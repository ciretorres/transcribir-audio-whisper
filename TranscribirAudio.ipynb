# %%
#https://github.com/openai/whisper
#https://platform.openai.com/docs/guides/speech-to-text/longer-inputs
# !pip install git+https://github.com/openai/whisper.git 
# !sudo apt update && sudo apt install ffmpeg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-8dve3j87
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-8dve3j87
#   Resolved https://github.com/openai/whisper.git to commit 5f9ac653b7f0fa772af9aa8e2cec89726b526c3e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ffmpeg-python==0.2.0
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from openai-whisper==20230308) (1.22.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (from openai-whisper==20230308) (1.13.1+cu116)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from openai-whisper==20230308) (4.65.0)
# Collecting triton==2.0.0
#   Downloading triton-2.0.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: numba in /usr/local/lib/python3.9/dist-packages (from openai-whisper==20230308) (0.56.4)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.9/dist-packages (from openai-whisper==20230308) (9.1.0)
# Collecting tiktoken==0.3.1
#   Downloading tiktoken-0.3.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 60.0 MB/s eta 0:00:00
# Requirement already satisfied: future in /usr/local/lib/python3.9/dist-packages (from ffmpeg-python==0.2.0->openai-whisper==20230308) (0.16.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.9/dist-packages (from tiktoken==0.3.1->openai-whisper==20230308) (2022.6.2)
# Collecting requests>=2.26.0
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 4.3 MB/s eta 0:00:00
# Collecting lit
#   Downloading lit-15.0.7.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 KB 9.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->openai-whisper==20230308) (3.9.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->openai-whisper==20230308) (3.22.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba->openai-whisper==20230308) (63.4.3)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba->openai-whisper==20230308) (0.39.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch->openai-whisper==20230308) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26.0->tiktoken==0.3.1->openai-whisper==20230308) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26.0->tiktoken==0.3.1->openai-whisper==20230308) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26.0->tiktoken==0.3.1->openai-whisper==20230308) (2022.12.7)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.1.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 1.9 MB/s eta 0:00:00
# Building wheels for collected packages: openai-whisper, lit
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20230308-py3-none-any.whl size=796923 sha256=190162d74b5211a84dd74c5711310f453821bf869a267590e372f55f4cee9de2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3_k31tu5/wheels/fe/03/29/e7919208d11b4ab32972cb448bb84a9a675d92cd52c9a48341
#   Building wheel for lit (setup.py) ... done
#   Created wheel for lit: filename=lit-15.0.7-py3-none-any.whl size=90003 sha256=590f5834cbfd66c2b991a0bb8999712a992a5df7f7b9fb5b69b204215c11154d
#   Stored in directory: /root/.cache/pip/wheels/b7/68/18/2ad49b416abb9139c8217c349fd9df0674da8f0d1952db2ea5
# Successfully built openai-whisper lit
# Installing collected packages: lit, ffmpeg-python, charset-normalizer, triton, requests, tiktoken, openai-whisper
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
# Successfully installed charset-normalizer-3.1.0 ffmpeg-python-0.2.0 lit-15.0.7 openai-whisper-20230308 requests-2.28.2 tiktoken-0.3.1 triton-2.0.0
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Hit:2 http://archive.ubuntu.com/ubuntu focal InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu2004/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Get:5 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu2004/x86_64  Release
# Get:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease [18.1 kB]
# Get:8 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Get:12 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3,019 kB]
# Hit:13 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Get:14 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1,312 kB]
# Hit:15 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Hit:16 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Get:17 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [2,544 kB]
# Get:18 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal/main Sources [2,397 kB]
# Get:19 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal/main amd64 Packages [1,136 kB]
# Fetched 10.8 MB in 3s (3,383 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 27 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 27 not upgraded.

# %%
# !whisper "/content/Lukas Avendaño 2.m4a" --language Spanish
# Out:
# [00:00.000 --> 00:10.000]  ¿Qué significa para ti ser?
# [00:10.000 --> 00:16.000]  ¿Qué significa para mí ser?
# [00:16.000 --> 00:22.000]  Más bien me gusta pensar a la inversa, lo que no significa.
# [00:22.000 --> 00:37.000]  Y pienso que lo que no significa es precisamente pensar en el imaginario como un suceso estático.
# [00:38.000 --> 00:55.000]  Me parece que no significa negar la capacidad de imaginar o reinventarse.
# [00:55.000 --> 01:02.000]  No significa privarse de la posibilidad de ser otra.
# [01:02.000 --> 01:11.000]  No significa privarse de la posibilidad del derecho a la felicidad y a la alegría y a la imaginación.
# [01:11.000 --> 01:16.000]  Quiero pensar que eso es lo que no significa más que lo que significa.
# [01:16.000 --> 01:23.000]  ¿Me es más complicado decir lo que significa que lo que no significa?
# [01:23.000 --> 01:31.000]  Bueno, creo que esta pregunta es más puntual sobre esta colaboración para poder realizarla en mis catas.
# [01:31.000 --> 01:39.000]  Si pudieras contarnos cómo se generó todo esto, de dónde proviene la propuesta.
# [01:39.000 --> 01:55.000]  Yo creo que la propuesta deviene de un estado psíquico que desconocemos, de un estadio de la psique.
# [01:55.000 --> 02:04.000]  Y que ese estadio de la psique por diferentes epistemologías o ontologías de repente las negamos.
# [02:04.000 --> 02:08.000]  Pero eso no quiere decir que no estén.
# [02:08.000 --> 02:20.000]  Y ese estado de la psique me parece que puede apelar o abonar a un estadio de la psique eurobórica, como el euroburo.
# [02:20.000 --> 02:33.000]  Y que en consecuencia, en tanto que el euroburo se asocia con esta imagen, este símbolo de la serpiente que se nace a sí misma,
# [02:33.000 --> 02:42.000]  me parece que ese estadio eurobórico también nos puede llevar a un estadio de la psique matricial.
# [02:42.000 --> 02:54.000]  En donde considero que es momento de que volvamos la vista y reconozcámonos que hemos estado equivocados.
# [02:54.000 --> 03:04.000]  Y estemos en la posibilidad de decidir tomar la decisión de romper el pacto patriarcal que hemos venido reafirmando,
# [03:04.000 --> 03:13.000]  a pesar de nuestras equivocaciones, que a pesar de nuestros errores, una y otra vez volvemos a lo mismo.
# [03:13.000 --> 03:22.000]  Y creo que es eso como reconocernos con esta humildad de que hemos estado equivocados y seguimos equivocándonos.
# [03:22.000 --> 03:39.000]  Y entonces, por un momento, creo que sería bonito pensar que podríamos decidir dejar este protagonismo que a veces queremos tener
# [03:39.000 --> 03:44.000]  o que siempre queremos no renunciar.
# [03:44.000 --> 03:50.000]  Yo creo que la inmiscata va en ese sentido, como una invitación a eso, a que nos repensemos,
# [03:50.000 --> 04:02.000]  a que reconsideremos que hemos estado equivocados desde el donde venimos y desde donde estamos.
# [04:02.000 --> 04:10.000]  Y quizás podamos imaginar un presente y un futuro más amoroso para todos.
# [04:10.000 --> 04:22.000]  Y bueno, en este sentido, no sé cómo se dio, o sea, fueron contigo, hablaron contigo sobre el proyecto.
# [04:22.000 --> 04:26.000]  ¿Tú fuiste de la iniciativa del proyecto?
# [04:26.000 --> 04:34.000]  Yo creo que ha sido como el danzar, como cuando tú dices que yo no sé bailar,
# [04:34.000 --> 04:41.000]  es que tengo dos pies izquierdos y aceptas, aún reconociéndote con los dos pies izquierdos,
# [04:41.000 --> 04:46.000]  aceptas pararte, ponerte de pie y aumentarte a la aventura de bailar.
# [04:46.000 --> 04:52.000]  Y cuando te das cuenta, estás bailando con el otro, con la otra persona.
# [04:52.000 --> 04:56.000]  Entonces, yo creo que el estar aquí ha sido una suerte así.
# [04:56.000 --> 05:03.000]  A mí me invitaron a bailar y yo dije, tengo dos pies izquierdos y me dijeron, no importa, ven a bailar.
# [05:03.000 --> 05:06.000]  Y entonces dije, ok, vamos a bailar.
# [05:06.000 --> 05:14.000]  Y en ese bailar, de repente yo piso a quien me le doy como un pisotón ahí,
# [05:14.000 --> 05:22.000]  cuando estoy bailando o la persona que me pisa también, pero nos vamos entendiendo.
# [05:22.000 --> 05:29.000]  Y en ese entendimiento creo que, y en ese bailar y en ese acompañarse,
# [05:29.000 --> 05:38.000]  porque también creo que la danza es eso, compañía, hemos concluido en estar ahora aquí.
# [05:38.000 --> 05:50.000]  Entonces, más que pensarlo como una decisión de una persona, ha sido una decisión de muchas personas.
# [05:50.000 --> 05:54.000]  ¿Y por qué una audición y por qué solo hombre?
# [05:54.000 --> 05:56.000]  ¿Por qué una audición?
# [05:56.000 --> 06:06.000]  Porque queríamos reconocer la diversidad, queríamos aproximarnos y encontrarnos con esa diversidad del país.
# [06:06.000 --> 06:15.000]  Anterior, si para el año 2000 me hubieran preguntado qué tan grande es México,
# [06:15.000 --> 06:22.000]  yo diría tal vez, pues no es tan grande, pero después que empiezas a tener otras experiencias con otros países,
# [06:22.000 --> 06:28.000]  te das cuenta de lo grande que es el país, de lo diverso que es el país.
# [06:28.000 --> 06:41.000]  Y en esa diversidad y en esa complejidad lanzamos la audición porque queríamos encontrarnos con esos otros imaginarios mexicanos.
# [06:41.000 --> 06:48.000]  Esos otros mexicanos que a veces escapan a nuestra comprensión porque estereotipamos que los mexicanos son así,
# [06:48.000 --> 06:54.000]  que las mexicanas son así, que los de Jalisco son así, que los de Jalisco son Jaliskillos,
# [06:54.000 --> 06:58.000]  que los de Guadalajara, que si los del Alto, que si no.
# [06:58.000 --> 07:04.000]  Entonces, estereotipamos y entonces dijimos no, abandonemos a la experiencia de encontrarnos con esos otros,
# [07:04.000 --> 07:08.000]  esas otras identidades, esas otras personalidades, esas otras personas.
# [07:08.000 --> 07:17.000]  Y a partir de esa convivencia fue que viene a colación el tema de la audición
# [07:17.000 --> 07:25.000]  y me gustaría decir que algo que se les comentó a los chicos que audicionaron fue
# [07:25.000 --> 07:33.000]  la eniscata no podría existir sin los 96 que aplicaron, pero que no están ahora.
# [07:33.000 --> 07:40.000]  Pero tampoco podrían existir sin esas personas que nos recibieron en cada uno de los siete municipios que visitamos.
# [07:40.000 --> 07:50.000]  Pero tampoco podría existir sin cada uno de esos danzantes que son representados por una mujer en estos municipios que visitamos.
# [07:50.000 --> 07:58.000]  Pero eso de la iniscata tampoco podría suceder sin esa tradición y esa memoria que se ha transmitido
# [07:58.000 --> 08:04.000]  tan generosamente de generación en generación para que un día aparecieran unos desconocidos
# [08:04.000 --> 08:12.000]  y quisieran platicar y ellas estuvieran en esa disposición de platicar, de compartir.
# [08:12.000 --> 08:17.000]  Entonces yo no pierdo de vista de que en la iniscata lo estamos haciendo todas.
# [08:17.000 --> 08:25.000]  Habrá 15 personas en el escenario, pero cada una de esas personas se multiplica exponencialmente
# [08:25.000 --> 08:30.000]  por esas otras personas que nos recibieron en Akati, que nos recibieron en Tonala,
# [08:30.000 --> 08:34.000]  que nos recibieron en Ciudad Busman, que nos recibieron y así.
# [08:34.000 --> 08:41.000]  Entonces me gusta imaginar y pensar que esas 15 personas que van a estar en la escena,
# [08:41.000 --> 08:52.000]  al final somos los que en este momento nos toca poner el cuerpo para trabajar por, con y desde esta ciudad.
# [08:53.000 --> 09:01.000]  ¿Y por qué hombres? Porque dentro del recorrido que hicimos recurrentemente
# [09:01.000 --> 09:11.000]  aparecía la figura femenina, la figura de la mujer, pero como un ente que dirige,
# [09:11.000 --> 09:19.000]  como un ente que organiza, como un ente que está tomando las decisiones más pertinentes
# [09:19.000 --> 09:27.000]  para su comunidad de ese momento. Y siempre hay un grupo de varones que está cuidando
# [09:27.000 --> 09:35.000]  que esas decisiones pertinentes que toma esa mujer puedan llevarse a cabo.
# [09:35.000 --> 09:46.000]  Entonces yo trasladado la iniscata al tema de la tradición, en las danzas de tradición en Jalisco
# [09:47.000 --> 09:54.000]  la mayoría si no es que casi todas siempre son encarnadas por cuerpos de hombres.
# [09:54.000 --> 10:00.000]  Y lo que estamos haciendo con la iniscata no es más que la continuidad de ese pensamiento,
# [10:00.000 --> 10:04.000]  pero no porque el hombre sea el protagonista, sino porque el hombre está al servicio
# [10:04.000 --> 10:11.000]  de un interés más superior que es precisamente esta imaginación que viene desde los mujerismos.
# [10:12.000 --> 10:19.000]  Quizás para cerrar esta plática, algo que realmente me generó mucho,
# [10:19.000 --> 10:29.000]  me descolocó fue cuando encontramos en cada municipio estos útiles para moler granos
# [10:29.000 --> 10:37.000]  que se les llaman huilanches, huilestas piedras con una cavidad por la fricción.
# [10:38.000 --> 10:45.000]  Y cuando yo vi estas piedras me llamaron mucho la atención y pregunté cómo se llamaban
# [10:45.000 --> 10:53.000]  y me dijeron son huilanches, pero después haciendo una revisión etimológica de la palabra huilanche
# [10:53.000 --> 11:00.000]  pues viene de huilatl y huilatl es paloma, pero huilatl también se refiere a los genitales femeninos
# [11:00.000 --> 11:06.000]  y huilatl muchas veces se usa para referirse a las trabajadoras sexuales
# [11:06.000 --> 11:12.000]  y entonces yo me dije en qué momento este elemento útil
# [11:12.000 --> 11:16.000]  que seguramente pudo haber tenido hasta una función ritual sagrada
# [11:16.000 --> 11:21.000]  en qué momento transfiguró a ser una puta, como sinónimo de puta
# [11:21.000 --> 11:26.000]  y entonces de ahí digo que estos cambios epistemológicos son tológicos
# [11:26.000 --> 11:32.000]  entonces digo no, yo creo que el huilanche tiene que recuperar su lugar protagonico
# [11:32.000 --> 11:39.000]  como un útil, además un útil que es activado por una mujer
# [11:39.000 --> 11:46.000]  y a la vez que es al final la que provee el alimento para toda la colectividad, para toda la comunidad
# [11:46.000 --> 11:53.000]  y en ese sentido creo que es donde me detengo a decir las cosas las hemos hecho tan mal
# [11:53.000 --> 12:00.000]  quizás en algún momento se nos ocurrió decir y usarlo como sinónimo de puta
# [12:00.000 --> 12:10.000]  pero seguramente hay que volverle su función sagrada al huilatl, al huilanche
# [12:10.000 --> 12:16.000]  y en la escena vamos a ver hombres
# [12:16.000 --> 12:22.000]  pero realmente estamos haciendo intentos desde nuestra
# [12:22.000 --> 12:29.000]  poniéndose en una posición de humildad queremos sonrar a las huilatl, al huilanche
# [12:29.000 --> 12:37.000]  a los mujerismos y esa fue una constante que apareció en esta zona lecustre de Jalisco
# [12:37.000 --> 12:42.000]  y me da mucho gusto que haya sido muy sorpresivo para mí
# [12:42.000 --> 12:45.000]  sobre todo porque en el imaginario de la mexicanidad dicen Jalisco
# [12:45.000 --> 12:50.000]  y inmediatamente se piensa o mucha gente piensa en el mariachi
# [12:50.000 --> 12:55.000]  en el charro mexicano y en el extranjero también
# [12:55.000 --> 13:00.000]  entonces en que momento toda esa feminidad, todos esos mujerismos
# [13:00.000 --> 13:10.000]  quedó sobrepasado por ese otro imaginario que se construyó y que es relativamente nuevo
# [13:10.000 --> 13:18.000]  apenas después de la revolución mexicana que se empieza a reconfigurar todos estos imaginarios
# [13:18.000 --> 13:23.000]  de lo que tendría que ser la identidad de la mexicanidad y entonces los machos mexicanos
# [13:23.000 --> 13:30.000]  robamos el spot y estuvimos en la primera escena pero hay un pensamiento antes
# [13:30.000 --> 13:33.000]  y ese me parece que no tiene que ver con el macho mexicano
# [13:33.000 --> 13:38.000]  pero sí con los mujerismos y es lo que intentamos hacer con la miscata
# [13:38.000 --> 13:41.000]  bueno y ya nada más así como para finalizar
# [13:41.000 --> 13:49.000]  no sé como ves cómo se desenvolve la danza en Ruego de la Jara
# [13:49.000 --> 13:53.000]  como lo percibiste dentro de la audición
# [13:53.000 --> 14:05.000]  pues yo creo que la muestra es que la mitad de los 14 danzantes, bailarines, artistas
# [14:05.000 --> 14:08.000]  como a tener en escena la mitad son de Jalisco
# [14:08.000 --> 14:13.000]  y la otra mitad, los otros siete vienen de siete estados diferentes de la República
# [14:13.000 --> 14:18.000]  entonces eso habla bien, eso habla bien
# [14:18.000 --> 14:26.000]  que hay una comunidad ansiosa de hacer, de crear, de poner el cuerpo
# [14:26.000 --> 14:30.000]  por su ciudad, por su estado, por su región
# [14:30.000 --> 14:33.000]  y por qué no, por su país
# [14:33.000 --> 14:36.000]  bueno, pues te agradezco muchísimo
# [14:36.000 --> 14:37.000]  no
# [14:37.000 --> 14:42.000]  y sobre todo porque sé que son tiempos reducidos

# %% [markdown]
# Videos de Youtube

# %%
#https://lablab.ai/t/whisper-transcribe-youtube-video
# !pip install pytube
#Importing Pytube library
import pytube
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytube
#   Downloading pytube-12.1.2-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 KB 3.5 MB/s eta 0:00:00
# Installing collected packages: pytube
# Successfully installed pytube-12.1.2

# %%
# Reading the YouTube link
video_2 = "https://youtu.be/S8GlE2k72c8"
data_2 = pytube.YouTube(video_2)

# Converting and downloading as 'MP4' file
audio_2 = data_2.streams.get_audio_only()
audio_2.download()
# Out:
# '/content/Screen Recording 2022 11 23 at 16 01 56.mp4'

# %%
# !whisper "/content/Screen Recording 2022 11 23 at 16 01 56.mp4" --language Spanish
# Out:
# [00:00.000 --> 00:04.000]  y con esto accedo al eje X.
# [00:04.000 --> 00:10.000]  Esto es un objeto de D3, es una selección de D3,
# [00:10.000 --> 00:14.000]  que es un grupo y adentro tiene textos.
# [00:14.000 --> 00:20.000]  Entonces, tú puedes seleccionar el texto y cambiar o modificar
# [00:20.000 --> 00:25.000]  este atributo de Transform y rotarlo, no sé, 50 grados o 90 grados
# [00:25.000 --> 00:30.000]  y trasladarlo, como darlo ahí bien.
# [00:30.000 --> 00:35.000]  Y lo que sí, a lo mejor hay que hacer pruebas, es como este tiempo, ¿no?
# [00:35.000 --> 00:38.000]  O sea, a lo mejor si tuvieran muchas gráficas,
# [00:38.000 --> 00:42.000]  pues hay que darle como un segundo para que se termine de renderizar la página
# [00:42.000 --> 00:46.000]  y que ya existan estos elementos para poderlo rotar.
# [00:46.000 --> 00:48.000]  Si yo aquí lo pusiera como cero,
# [00:48.000 --> 00:51.000]  probablemente ni siquiera se ha generado la gráfica
# [00:51.000 --> 00:55.000]  y yo ya estoy intentando rotar algo que no existe.
# [00:55.000 --> 00:59.000]  Entonces, nada más probar con una función así.
# [00:59.000 --> 01:04.000]  Si quieres que la dejo aquí en el...
# [01:04.000 --> 01:06.000]  Sí, por favor.
# [01:06.000 --> 01:11.000]  Y me recomiendas que solo lo aplique
# [01:11.000 --> 01:15.000]  cuando esté en versión móvil o que esté en ambas.
# [01:15.000 --> 01:20.000]  Y creo que con eso, ¿cómo ves?
# [01:20.000 --> 01:23.000]  Perdón, tenía el micrófono apagado.
# [01:23.000 --> 01:25.000]  Sí, muchas gracias.
# [01:25.000 --> 01:30.000]  Te preguntaba si me recomiendas que lo deje para solamente la versión móvil
# [01:30.000 --> 01:33.000]  o que esté ya desteciteado para ambas.
# [01:39.000 --> 01:41.000]  Es una buena pregunta.
# [01:41.000 --> 01:46.000]  O sea, creo que lo ideal sería hacerlo solo para versión móvil,
# [01:46.000 --> 01:48.000]  porque eso se implica más código,
# [01:48.000 --> 01:53.000]  se implica poner ahí un window, ¿qué?
# [01:53.000 --> 01:57.000]  Event, algo así, Event Listener.
# [01:57.000 --> 02:01.000]  Y meter ahí que si la pantalla es más chica o más grande,
# [02:01.000 --> 02:03.000]  rote o no lo rote, ¿no?
# [02:03.000 --> 02:07.000]  Pero yo creo que lo mejor sería ahorita así rotarlo.
# [02:07.000 --> 02:09.000]  Sí, está bien.
# [02:10.000 --> 02:11.000]  En ambas versiones.
# [02:11.000 --> 02:16.000]  Orita creo que solo aplicaría para las que son horizontales,
# [02:16.000 --> 02:18.000]  barras horizontales.
# [02:18.000 --> 02:20.000]  Ok.
# [02:20.000 --> 02:21.000]  Sí.
# [02:21.000 --> 02:28.000]  Y es que sabes también, creo que hay algo que no he puesto como propiedad,
# [02:28.000 --> 02:34.000]  pero no tardo mucho solo aquí en barras.
# [02:34.000 --> 02:38.000]  A ver, o porque si sí lo he puesto como propiedad,
# [02:38.000 --> 02:39.000]  no lo he puesto.
# [02:39.000 --> 02:45.000]  Es ejeche, barras.
# [02:58.000 --> 03:03.000]  O sea, aquí tú le puedes poner a especificar a tu eje,
# [03:03.000 --> 03:08.000]  ¿cuántos datos quieres que te ponga?
# [03:08.000 --> 03:09.000]  Sí.
# [03:09.000 --> 03:12.000]  O sea, a lo mejor lo está haciendo en automático para el eje X,
# [03:12.000 --> 03:15.000]  porque por lo que veo no estamos especificando en el eje X
# [03:15.000 --> 03:18.000]  cuántos conectes, a lo mejor por eso encima.
# [03:18.000 --> 03:23.000]  Y es también quizás este numerito dejarlo como una propiedad
# [03:23.000 --> 03:25.000]  que se pueda modificar desde afuera,
# [03:25.000 --> 03:27.000]  pero creo que ahorita ya no da chances,
# [03:27.000 --> 03:29.000]  hay que agregarlo luego.
# [03:29.000 --> 03:31.000]  Sí, después sí.
# [03:31.000 --> 03:33.000]  Para que no se empalmen, ¿verdad?
# [03:33.000 --> 03:36.000]  Que se ven como limitados, pues.
# [03:36.000 --> 03:39.000]  Sí, poder controlar eso, porque está bueno.
# [03:39.000 --> 03:40.000]  Ok.
# [03:40.000 --> 03:41.000]  Va.
# [03:41.000 --> 03:42.000]  Va.
# [03:42.000 --> 03:44.000]  Salen, pues.

# %%
#https://github.com/jiaaro/pydub
# !pip install git+https://github.com/jiaaro/pydub.git@master
from pydub import AudioSegment
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/jiaaro/pydub.git@master
#   Cloning https://github.com/jiaaro/pydub.git (to revision master) to /tmp/pip-req-build-c_hvs7hq
#   Running command git clone --filter=blob:none --quiet https://github.com/jiaaro/pydub.git /tmp/pip-req-build-c_hvs7hq
#   Resolved https://github.com/jiaaro/pydub.git to commit 996cec42e9621701edb83354232b2c0ca0121560
#   Preparing metadata (setup.py) ... done

# %%
#song = AudioSegment.from_file("/content/Screen Recording 2022-11-23 at 16.01.56.mp4", "mp4")

song = AudioSegment.from_file("/content/Screen Recording 2022-11-23 at 16.01.56 - Compressed with FlexClip.webm", "webm")

#song = AudioSegment.from_flv("/content/Screen Recording 2022-11-23 at 16.01.56 - Compressed with FlexClip.flv")

# PyDub handles time in milliseconds
ten_minutes = 10 * 60 * 1000

first_10_minutes = song[:ten_minutes]

# pydub does things in milliseconds
ten_seconds = 10 * 1000

first_10_seconds = song[:ten_seconds]

#last_5_seconds = song[-5000:]

first_10_minutes.export("good_morning_10.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='good_morning_10.mp3'>

# %%
song
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
# !whisper "/content/Screen Recording 2022-11-23 at 16.01.56 - Compressed with FlexClip.webm" --language Spanish
# Out:
# [00:00.000 --> 00:11.520]  ya que accedo al componente y con esto accedo al EGX, esto es un objeto de D3, es una selección
# [00:11.520 --> 00:18.760]  de D3 que es un grupo y adentro tiene textos entonces ya tú puedes como seleccionar el
# [00:18.760 --> 00:26.960]  texto y cambiar o modificar este atributo de transform y rotarlo no sé 50 grados o 90
# [00:26.960 --> 00:34.360]  grados y trasladarlo como darlo ahí bien y lo que sí a lo mejor hay que hacer pruebas es como
# [00:34.360 --> 00:40.080]  este tiempo ok a lo mejor si tuvieran muchas gráficas pues hay que darle como un segundo
# [00:40.080 --> 00:45.720]  para que se termine de renderizar la página y que ya existan estos elementos para poderlo
# [00:45.720 --> 00:51.360]  rotar si yo aquí le pusiera como cero probablemente ni siquiera se ha generado la gráfica y yo
# [00:51.360 --> 00:59.120]  estoy intentando rotar algo que no existe pues es nada más probar con una función así si queres
# [00:59.120 --> 01:11.720]  que la dejo aquí en el aquí y me recomiendas que sólo lo aplique cuando esté en versión móvil o

# %%
# !whisper "/content/Screen Recording 2022-11-23 at 16.01.56 - Compressed with FlexClip.webm" --language Spanish --model large
# Out:
# [00:00.000 --> 00:10.720]  entonces ya aquí accedo al componente y con esto accedo al eje X, que esto es un objeto de D3,
# [00:10.720 --> 00:17.840]  es una selección de D3, que es un grupo y adentro tiene textos, entonces ya tú puedes
# [00:17.840 --> 00:25.400]  como seleccionar el texto y cambiar o modificar este atributo de transform y rotarlo, no sé,
# [00:25.400 --> 00:33.560]  50 grados o 90 grados y trasladarlo, acomodarlo ahí bien y lo que sí a lo mejor hay que hacer
# [00:33.560 --> 00:40.080]  pruebas es como este tiempo, a lo mejor si tuviera muchas gráficas pues hay que darle como un segundo
# [00:40.080 --> 00:46.040]  para que se termine de renderizar la página y que ya existan estos elementos para poderlo rotar,
# [00:46.040 --> 00:51.480]  si yo aquí le pusiera como cero probablemente ni siquiera se ha generado la gráfica y yo ya
# [00:51.480 --> 00:58.000]  estoy intentando rotar algo que no existe, pues es nada más probar con una función así,
# [00:58.000 --> 01:10.280]  si quieres te la dejo aquí en el... aquí? Sí por favor, y me recomiendas que solo lo aplique
# [01:10.280 --> 01:12.960]  cuando esté en versión móvil o que esté...

# %%
# Reading the YouTube link
video = "https://www.youtube.com/watch?v=4MVYOHcMOS4"
data = pytube.YouTube(video)

# Converting and downloading as 'MP4' file
audio = data.streams.get_audio_only()
audio.download()
# Out:
# '/content/Tasa de Interés  ¿Cómo Funciona ¿Porque sube y baja.mp4'

# %%
# !whisper "/content/Tasa de Interés  ¿Cómo Funciona ¿Porque sube y baja.mp4" --language Spanish
# Out:
# [00:00.000 --> 00:05.160]  Quieres hacer tu primera inversión, pedir un préstamo o sacar una tarjeta de crédito,
# [00:05.160 --> 00:08.360]  pero no estás seguro de cómo funcionan los intereses.
# [00:08.360 --> 00:13.200]  No te preocupes, en este vídeo veremos todo lo que requiere saber acerca de los intereses
# [00:13.200 --> 00:16.240]  y cómo estos pueden ser tu aliado o tu enemigo.
# [00:16.240 --> 00:21.840]  Quédate hasta el final del vídeo porque hablaremos de algunos conceptos económicos muy interesantes
# [00:21.840 --> 00:27.800]  que explican por qué suben y por qué bajan las tasas de interés en México y en muchos otros países.
# [00:27.840 --> 00:33.520]  Ayúdame a reventar ese botón de like y suscribirte para que no te pierdas ninguno de mis otros vídeos
# [00:33.520 --> 00:37.560]  en los que estaré hablando de inversiones, bolsa, finanzas personales
# [00:37.560 --> 00:41.240]  y otros temas que te ayudarán a alcanzar la libertad financiera.
# [00:41.240 --> 00:45.920]  El interés es un índice que mide la rentabilidad de los ahorros e inversiones,
# [00:45.920 --> 00:48.400]  así como también el costo de un crédito.
# [00:48.400 --> 00:51.840]  Algunos se refieren al interés como el precio del dinero.
# [00:51.840 --> 00:56.160]  En pocas palabras, el interés es el costo que tiene pedir dinero prestado
# [00:56.160 --> 00:59.080]  y la ganancia que se puede obtener al prestar dinero.
# [00:59.080 --> 01:04.080]  Hablemos de dos conceptos súper importantes que debes conocer sobre las tasas de interés.
# [01:04.080 --> 01:08.000]  Al pedir un préstamo o hacer una inversión hay dos tipos de intereses,
# [01:08.000 --> 01:11.520]  los intereses fijos y los intereses variables.
# [01:11.520 --> 01:15.080]  ¿Cuál es la diferencia entre el interés fijo y el interés variable?
# [01:15.080 --> 01:21.280]  Es muy sencillo, el interés fijo es el que permanece igual a lo largo de todo el plazo de inversión.
# [01:21.440 --> 01:24.400]  Ejemplos de algunas plataformas que cuentan con interés fijo,
# [01:24.400 --> 01:29.800]  son CETES directo, CUBO financiero, FINSUS, supertazas y algunas más.
# [01:29.800 --> 01:32.280]  Por otro lado, tenemos al interés variable,
# [01:32.280 --> 01:38.800]  que como su nombre lo indica, tiene variaciones a lo largo de todo el plazo de inversión o el plazo del préstamo.
# [01:38.800 --> 01:42.480]  Algunos ejemplos de instrumentos de inversión con tasa de interés variable
# [01:42.480 --> 01:45.720]  son la bolsa de valores, la inversión en criptomonedas
# [01:45.720 --> 01:48.680]  y la inversión en plataformas como Dindac Timber
# [01:48.680 --> 01:53.840]  que invierten en fondos de inversión que cotizan en bolsa y que tienen variaciones diariamente.
# [01:53.840 --> 01:55.760]  Recordemos que la inversión en Dind,
# [01:55.760 --> 02:00.040]  a pesar de estar en un fondo de inversión con variaciones, es bastante segura
# [02:00.040 --> 02:04.000]  y si quieres saber cómo puedes invertir en esa plataforma, te dejaré un vídeo acá arriba.
# [02:04.000 --> 02:09.920]  Probablemente hayas escuchado acerca del interés compuesto y lo mágico que puede ser para tus inversiones.
# [02:09.920 --> 02:14.200]  El interés compuesto consiste en que las ganancias que vas obteniendo por tus inversiones
# [02:14.280 --> 02:18.800]  se tomen en cuenta para generar nuevos rendimientos formando una bola de nieve.
# [02:18.800 --> 02:20.400]  Aquí tengo un ejemplo muy rápido.
# [02:20.400 --> 02:24.680]  Supongamos que tú inviertes mil pesos a una tasa del 10% anual,
# [02:24.680 --> 02:27.120]  al final del año tendrás mil 100 pesos,
# [02:27.120 --> 02:31.200]  pero el siguiente año el 10% no se va a basar sobre los mil pesos iniciales,
# [02:31.200 --> 02:33.520]  se va a basar sobre los mil 100 que ya tienes,
# [02:33.520 --> 02:36.880]  por lo que ahora en lugar de ganar 100 pesos como el año pasado,
# [02:36.880 --> 02:39.000]  vas a ganar 110 pesos
# [02:39.000 --> 02:43.040]  y así va aumentando de forma exponencial la cantidad que vas ganando
# [02:43.120 --> 02:44.760]  gracias al interés compuesto.
# [02:44.760 --> 02:46.000]  Mucho cuidado,
# [02:46.000 --> 02:48.920]  porque puedes aprovechar el interés compuesto en tus inversiones,
# [02:48.920 --> 02:52.200]  pero también puede ser fatal en el caso de que pidas algún préstamo
# [02:52.200 --> 02:55.720]  y los intereses se vayan acumulando, aumentando tu deuda.
# [02:55.720 --> 02:58.720]  El interés compuesto no es el único tipo de interés que existe,
# [02:58.720 --> 03:00.560]  también existe el interés simple,
# [03:00.560 --> 03:04.520]  este es un poco más extraño verlo en inversiones o en préstamos,
# [03:04.520 --> 03:09.160]  pero consiste en que los intereses únicamente se van a aplicar a la cantidad inicial.
# [03:09.160 --> 03:13.440]  Ahora, muchos me hacen la pregunta de cuál es el mejor instrumento para invertir
# [03:13.440 --> 03:15.600]  utilizando interés compuesto
# [03:15.600 --> 03:17.680]  y la respuesta es bastante sencilla,
# [03:17.680 --> 03:20.480]  tú puedes invertir en cualquier instrumento de inversión
# [03:20.480 --> 03:22.800]  y si tú reinviertes tus ganancias,
# [03:22.800 --> 03:26.560]  automáticamente vas a estar aprovechando el poder del interés compuesto.
# [03:27.080 --> 03:30.680]  Dos conceptos súper importantes que puede que sean un poco más financieros
# [03:30.680 --> 03:32.080]  y no tan escuchados,
# [03:32.080 --> 03:35.720]  son las tasas efectivas y las tasas nominales,
# [03:35.720 --> 03:37.080]  ¿cuál es la diferencia?
# [03:37.120 --> 03:40.760]  La tasa efectiva es el interés pagado al final del periodo
# [03:40.760 --> 03:42.640]  con capitalización de intereses
# [03:42.640 --> 03:46.600]  y es la tasa que regularmente se usa en inversiones y préstamos.
# [03:46.600 --> 03:48.040]  Vamos a dar un ejemplo,
# [03:48.040 --> 03:54.320]  si inviertes mil pesos y te dicen que tu inversión tiene una tasa anual efectiva del 8%,
# [03:54.320 --> 03:58.360]  al final del periodo tendrías tu inversión inicial que son los mil pesos
# [03:58.360 --> 04:01.000]  más los intereses que son los 80 pesos,
# [04:01.000 --> 04:03.080]  serían mil 80 pesos.
# [04:03.080 --> 04:06.880]  El próximo año el interés estará basado sobre el nuevo capital
# [04:06.880 --> 04:08.400]  que son los mil 80 pesos
# [04:08.400 --> 04:12.400]  y al final del año tendrás 86.4 pesos de rendimiento
# [04:12.400 --> 04:14.640]  en lugar de 80 pesos como el año pasado.
# [04:14.640 --> 04:18.560]  La tasa efectiva es la que está presente en el interés compuesto.
# [04:18.560 --> 04:23.440]  La tasa de interés nominal es aquella que solo se calcula en base a la cantidad inicial,
# [04:23.440 --> 04:25.760]  como si fuera interés simple.
# [04:25.760 --> 04:27.960]  Es importante que cuando pidas un préstamo
# [04:27.960 --> 04:31.760]  calcules cuál será la tasa anual efectiva que estarás pagando.
# [04:31.760 --> 04:34.600]  En ocasiones te ofrecen préstamos con tasas mensuales
# [04:34.640 --> 04:39.320]  y es esencial que tú cambieses esa tasa mensual a una tasa anual
# [04:39.320 --> 04:42.120]  para saber qué será lo que te van a estar cobrando realmente,
# [04:42.120 --> 04:44.240]  porque puede ser una diferencia muy grande.
# [04:44.240 --> 04:45.360]  Ha quitado un ejemplo,
# [04:45.360 --> 04:49.360]  si tú pides un préstamo con una tasa de interés mensual del 4%,
# [04:49.360 --> 04:54.040]  algunos pensarían que al final del año únicamente van a pagar ese 4 por los 12 meses,
# [04:54.040 --> 04:55.680]  o sea 48%,
# [04:55.680 --> 04:57.160]  pero esto no es así.
# [04:57.160 --> 04:58.840]  Como el interés es compuesto,
# [04:58.840 --> 05:03.240]  al final del año terminarás pagando aproximadamente un 60% de interés
# [05:03.240 --> 05:06.040]  en lugar del 48% que tenías pensado.
# [05:06.040 --> 05:10.640]  Vamos a ver un ejemplo en Excel de cómo puedes convertir una tasa mensual a una tasa anual
# [05:10.640 --> 05:14.800]  y quédate porque este tipo de habilidades son súper importantes para poder saber
# [05:14.800 --> 05:18.520]  cuánto te van a estar cobrando realmente en un crédito o en algún préstamo.
# [05:18.520 --> 05:19.800]  Te mostraré dos ejemplos.
# [05:19.800 --> 05:23.880]  El primero será de un préstamo con una tasa del 4% mensual compuesto
# [05:23.880 --> 05:28.480]  y el segundo será con una tasa del 0.5% diario compuesto.
# [05:28.480 --> 05:32.200]  Para que veas lo que realmente estarías pagando con préstamos como estos.
# [05:32.240 --> 05:34.080]  Ahora vamos con los ejemplos de Excel.
# [05:34.080 --> 05:40.360]  El primero es un préstamo de 10.000 pesos con una tasa del 4% mensual mensual efectiva.
# [05:40.360 --> 05:44.560]  Esto quiere decir que cada mes te van a cobrar un 4% de interés
# [05:44.560 --> 05:47.720]  y el interés que se genere te lo van a añadir a la deuda,
# [05:47.720 --> 05:50.680]  por lo que a final de cuentas va a estar pagando un interés mucho más alto.
# [05:50.680 --> 05:54.600]  Muchas personas creerían que por tener esa tasa del 4% mensual mensual,
# [05:54.600 --> 05:58.480]  al final del año solo pagarán un 48% anual,
# [05:58.480 --> 06:01.320]  que es el 4 por los 12 meses del año,
# [06:01.360 --> 06:02.800]  pero esto no es así.
# [06:02.800 --> 06:07.280]  El 48% es únicamente la tasa nominal, no es la efectiva.
# [06:07.280 --> 06:10.960]  Y para conseguir la efectiva, lo que realmente vamos a estar pagando por año,
# [06:10.960 --> 06:12.960]  tenemos que utilizar la siguiente fórmula,
# [06:12.960 --> 06:15.840]  es una fórmula de Excel que se llama EFFECT.
# [06:15.840 --> 06:18.640]  Cúlbunicamente tienes que poner igual, EFFECT,
# [06:18.640 --> 06:22.840]  y entre paréntesis tienes que poner la tasa nominal y el número de periodos,
# [06:22.840 --> 06:25.880]  en este caso son 12 porque son 12 meses en un año.
# [06:25.880 --> 06:30.000]  De esta forma obtenemos lo que realmente vamos a estar pagando, la tasa efectiva,
# [06:30.080 --> 06:31.840]  y si no quieres usar fórmulas de Excel,
# [06:31.840 --> 06:34.280]  también puedes intentar hacerlo con esta fórmula,
# [06:34.280 --> 06:36.200]  que es una fórmula matemática,
# [06:36.200 --> 06:41.800]  que básicamente es 1 más la tasa nominal entre 12 elevado a la 2 entre 1 menos 1.
# [06:42.720 --> 06:45.360]  Obtenemos el mismo resultado con cualquiera de las dos.
# [06:45.360 --> 06:49.400]  A final de cuentas obtenemos que la tasa real que tú vas a estar pagando cada año,
# [06:49.400 --> 06:53.520]  es mucho más alta de lo que las personas normalmente suelen creer.
# [06:53.520 --> 06:59.120]  Por lo general las personas creen que les van a cobrar únicamente el 48% o sea 4.800 pesos,
# [06:59.120 --> 07:03.520]  pero realmente estarán pagando 6.000 pesos aproximadamente de puros intereses.
# [07:04.080 --> 07:06.000]  Ahora, vamos con el segundo ejemplo.
# [07:06.000 --> 07:09.480]  En el segundo ejemplo tenemos un préstamo de 1.000 pesos únicamente,
# [07:10.320 --> 07:17.440]  y este préstamo tiene una tasa del 0.5% muy bajita, pero es diariamente, aquí está lo peligroso.
# [07:17.440 --> 07:21.280]  Si tenemos una tasa diaria, cada día se van a generar intereses,
# [07:21.280 --> 07:23.480]  e dos intereses se van a añadir a la deuda,
# [07:23.480 --> 07:26.640]  y el siguiente día el interés va a ser mucho mayor que el día anterior.
# [07:27.120 --> 07:32.320]  Entonces, si calculamos la tasa nominal que es multiplicar esta tasa por el número 10 en un año,
# [07:32.320 --> 07:36.400]  tenemos que es un 182.50% anual.
# [07:36.400 --> 07:42.240]  Muchos creerían de nuevo que van a estar pagando esta tasa al final del año, o sea 1.825 pesos,
# [07:42.240 --> 07:45.200]  pero realmente van a estar pagando esta tasa efectiva,
# [07:45.200 --> 07:50.480]  que la conseguimos con la fórmula que acabamos de ver, y que es de un 517%.
# [07:50.480 --> 07:53.680]  Es prácticamente 5 veces la cantidad que tú pediste prestada,
# [07:53.760 --> 07:57.200]  y en lugar de estar pagando 1.800 pesos de intereses como tú creías,
# [07:57.200 --> 08:02.000]  vas a estar pagando 5.174 pesos de puro interés.
# [08:04.480 --> 08:10.000]  Espero que con estos ejemplos hayan entendido la importancia de convertir las tasas mensuales,
# [08:10.000 --> 08:14.640]  diarias, semanales o de cualquier periodo a una tasa efectiva anual,
# [08:14.640 --> 08:19.040]  para que realmente sepan cuánto interés van a estar pagando en el año.
# [08:19.760 --> 08:22.560]  Ahora que ya conocemos cómo funcionan las tasas de interés,
# [08:22.560 --> 08:26.960]  y cómo podemos convertir una tasa mensual o diaria a una tasa anual,
# [08:26.960 --> 08:31.200]  llegó el momento de revisar algunos conceptos económicos bastante interesantes.
# [08:31.200 --> 08:35.520]  Probablemente hayas escuchado acerca de la tasa de referencia de Banjico,
# [08:35.520 --> 08:40.640]  el Banco Central de México tiene como objetivo mantener la inflación baja y estable,
# [08:40.640 --> 08:45.440]  y para lograrlo se deben hacer varios ajustes, entre ellos el de la tasa de referencia.
# [08:45.440 --> 08:49.920]  La tasa de referencia es una tasa base para las instituciones bancarias en México,
# [08:49.920 --> 08:56.320]  y los bancos ofrecen créditos basándose en esa tasa y agregándole algunos puntos para obtener una ganancia.
# [08:56.320 --> 08:59.360]  Es por esto que cuando las tasas de referencia bajan,
# [08:59.360 --> 09:02.880]  el costo de adquirir un préstamo o un crédito también es menor,
# [09:02.880 --> 09:07.920]  y cuando la tasa de referencia sube, el costo de pedir dinero prestado es mucho mayor.
# [09:07.920 --> 09:13.440]  La tasa de referencia no sólo afecta a los préstamos y créditos, también afecta a las inversiones.
# [09:13.440 --> 09:19.040]  Con la crisis actual por la pandemia y por los problemas económicos que ya se venía cargando el país,
# [09:19.120 --> 09:23.120]  tuvimos una bajada en las tasas de referencia en los últimos meses,
# [09:23.120 --> 09:29.920]  y con ellas comenzaron a bajar las tasas de rendimiento de las inversiones de renta fija como los setes y las soffipos.
# [09:29.920 --> 09:36.480]  Por darte un ejemplo, setes en 2019 ofrecía una tasa anual del 8% aproximadamente,
# [09:36.480 --> 09:40.480]  y actualmente esa tasa ya bajó hasta un 4% anual.
# [09:40.480 --> 09:44.480]  Por otro lado, Finsus, un soffipo que ya hay recomendado en el canal,
# [09:44.480 --> 09:49.760]  bajó sus tasas por el plazo de inversión de un año de un 12% a un 10% anual.
# [09:49.760 --> 09:55.520]  Te dejaré mis tutoriales para que puedas invertir en setes y en Finsus acá arriba y en la descripción del vídeo.
# [09:55.520 --> 09:59.200]  Ahora, ¿por qué suben y bajan las tasas de referencia?
# [09:59.200 --> 10:05.040]  Explicado de forma simple, el banco central sube las tasas de referencia para incentivar el ahorro
# [10:05.040 --> 10:07.920]  y evitar posibles subidas bruscas en la inflación.
# [10:07.920 --> 10:13.040]  Recordemos que el comportamiento de la inflación tiene relación con la ley de oferta y demanda,
# [10:13.040 --> 10:17.840]  en donde si la demanda excede la capacidad de exportación o producción de bienes,
# [10:17.840 --> 10:22.240]  comienzan a aumentar los precios de los productos y con ello la inflación.
# [10:22.240 --> 10:26.080]  La tasa de referencia es reducida en momentos de crisis,
# [10:26.080 --> 10:31.360]  y esta reducción tiene como objetivo incentivar el consumo y reactivar la economía.
# [10:31.360 --> 10:35.200]  Al disminuir la tasa de referencia, los instrumentos de inversión en el país
# [10:35.200 --> 10:40.800]  comienzan a ofrecer rendimientos cada vez más bajos y los ciudadanos ven más atractivo
# [10:40.800 --> 10:44.480]  gastar su dinero en la compra de bienes muebles como automóviles,
# [10:44.480 --> 10:48.560]  porque los créditos para la compra de estos son mucho más accesibles.
# [10:48.560 --> 10:53.600]  De igual forma, cuando los inversionistas ven que los rendimientos por su dinero están bajando,
# [10:53.600 --> 10:57.600]  comienzan a buscar inversiones más rentables como la inversión en bolsa
# [10:57.600 --> 11:02.480]  y también comienzan a emprender negocios nuevos que generen más empleos
# [11:02.480 --> 11:05.920]  para reactivar la economía e impulsar el desarrollo del país.
# [11:05.920 --> 11:11.280]  En conclusión, es sumamente importante conocer cómo funcionan las tasas de interés
# [11:11.280 --> 11:16.160]  para que las puedas utilizar a tu favor y que realmente sepas cuánto te van a cobrar
# [11:16.160 --> 11:18.480]  cuando adquires algún préstamo o crédito.
# [11:18.480 --> 11:21.360]  Te invito a que te unas a nuestra comunidad de inversionistas en Discord,
# [11:21.360 --> 11:26.560]  donde platicamos de tarjetas de débito, inversiones, criptomonedas, pago de impuestos
# [11:26.560 --> 11:28.720]  y un montón de cosas súper interesantes.
# [11:28.720 --> 11:33.040]  Es completamente gratuito unirse y te dejaré la invitación aquí abajo en la descripción
# [11:33.120 --> 11:34.320]  y en el primer comentario.
# [11:34.320 --> 11:36.480]  También te invito a que te pases por mi Twitch.
# [11:36.480 --> 11:38.960]  Es completamente gratis y me puedes seguir allá también.
# [11:38.960 --> 11:42.080]  Hago livestreams todas las semanas platicando de inversiones,
# [11:42.080 --> 11:44.960]  analizando acciones y resolviendo sus dudas.
# [11:44.960 --> 11:48.640]  Eso ha sido todo por este vídeo y espero que hayas aprendido algo.
# [11:48.640 --> 11:51.200]  Recuerda darle like, compartirlo con tus amigos,
# [11:51.200 --> 11:53.600]  dejarme un comentario y suscribirte.
# [11:53.600 --> 11:56.000]  Estaré subiendo más vídeos de plataformas de inversión,
# [11:56.000 --> 12:00.480]  tienes problema de manejo de tu dinero y muchos otros temas bastante interesantes.
# [12:00.480 --> 12:03.120]  Así que, dale clic en la campanita, nos vemos.
